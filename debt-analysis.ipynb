# %%
import numpy as np
import pandas as pd

df = pd.read_excel('subnational-debt-OECD.xlsx', sheetname="Sheet1")
df.describe().round()
# Out:
#        Subnational Debt  Population       Area  Debt per km squared  \
# count              32.0        34.0       34.0                 32.0
# mean              353.0     37848.0  1013720.0             782808.0
# std               953.0     60498.0  2447630.0            1178953.0
# min                 1.0       327.0     2586.0              17956.0
# 25%                 7.0      5508.0    53876.0              95874.0
# 50%                53.0     10726.0   186664.0             214041.0
# 75%               225.0     49434.0   398888.0             732857.0
# max              5127.0    319173.0  9161923.0            4664686.0
#
#        Debt per person  Population Density
# count             32.0                34.0
# mean            5869.0               144.0
# std             6186.0               139.0
# min              172.0                 3.0
# 25%             1306.0                31.0
# 50%             4220.0               103.0
# 75%             8797.0               213.0
# ...
