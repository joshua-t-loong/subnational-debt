# %%
import numpy as np
import pandas as pd

df = pd.read_excel('subnational-debt-OECD.xlsx', sheetname="Sheet1")
df.describe()
# Out:
#        Subnational Debt     Population          Area  Debt per km squared  \
# count         32.000000      34.000000  3.400000e+01         3.200000e+01
# mean         352.631250   37848.323529  1.013720e+06         7.828084e+05
# std          953.053084   60498.176547  2.447630e+06         1.178953e+06
# min            1.400000     327.000000  2.586000e+03         1.795640e+04
# 25%            7.100000    5508.000000  5.387550e+04         9.587418e+04
# 50%           53.450000   10726.000000  1.866645e+05         2.140407e+05
# 75%          225.300000   49434.000000  3.988875e+05         7.328570e+05
# max         5126.800000  319173.000000  9.161923e+06         4.664686e+06
#
#        Debt per person  Population Density  Share of GDP  \
# count        32.000000           34.000000     31.000000
# mean       5869.425000          143.801471     13.691691
# std        6185.708149          139.438475     13.471881
# min         172.300000            3.070000      0.700933
# ...
