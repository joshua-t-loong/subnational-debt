# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_excel('subnational-debt-OECD.xlsx', sheetname="Sheet1")

df
# Out:
#            Country  Subnational Debt  Population     Area  \
# 0        Australia             214.0       23639  7703354
# 1          Austria              54.3        8544    82409
# 2          Belgium              97.2       11157    30326
# 3           Canada            1017.8       35540  9093507
# 4   Czech Republic              13.8       10525    77227
# 5          Denmark              29.4        5643    42959
# 6          Estonia               1.7        1316    43432
# 7          Finland              27.3        5463   303891
# 8           France             287.6       66169   647795
# 9          Germany            1104.5       80983   357168
# 10          Greece               3.3       10927   130820
# 11         Hungary               1.7        9867    93028
# 12         Iceland               1.8         327   100243
# 13         Ireland               7.1        4615    68394
# 14         Isreael               7.1        8212    21643
# ...

# %%
sns.scatter(data=df, x="Debt per km squared", y="Population Density", hue="Country")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-37f45356268d> in <module>()
# ----> 1 sns.scatter(data=df, x="Debt per km squared", y="Population Density", hue="Country")
#
# NameError: name 'sns' is not defined
