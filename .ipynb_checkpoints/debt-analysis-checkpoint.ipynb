# %%
import numpy as np
import pandas as pd

df = pd.read_excel('subnational-debt-OECD.xlsx', sheetname="Sheet1")
df.describe(include="all")
# Out:
#        Country Subnational Debt     Population          Area  \
# count       34               34      34.000000  3.400000e+01
# unique      34               31            NaN           NaN
# top         US              n/a            NaN           NaN
# freq         1                2            NaN           NaN
# mean       NaN              NaN   37848.323529  1.013720e+06
# std        NaN              NaN   60498.176547  2.447630e+06
# min        NaN              NaN     327.000000  2.586000e+03
# 25%        NaN              NaN    5508.000000  5.387550e+04
# 50%        NaN              NaN   10726.000000  1.866645e+05
# 75%        NaN              NaN   49434.000000  3.988875e+05
# max        NaN              NaN  319173.000000  9.161923e+06
#
#        Debt per km squared Debt per person  Population Density
# count                   34              34           34.000000
# unique                  33              33                 NaN
# ...
